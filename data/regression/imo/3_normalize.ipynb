# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

df = pd.read_csv('imo_board_groupby_year_dropna.csv')
col = ['year', 'count_country', 'all', 'p1', 'p2', 'p3', 'p4', 'p5', 'p6']
df[col] = df[col].astype(np.int64)
display(df.head(10))
# Out:
#    year  count_country  all   p1   p2   p3   p4   p5   p6
# 0  1959              2    9   25   55   38   19   13   23
# 1  1960              1    8   38   26   12   36   18   17
# 2  1961              2    9   29   28   23   24   27   17
# 3  1962              3   17   92   77   83   67   71   38
# 4  1963              2   16   56   52   31   22   38   97
# 5  1964              9   72  412  310  382  107  274  352
# 6  1965             10   80  219  216  322  335  303  220
# 7  1966              7   27  144  163  126  127  135  198
# 8  1967              8   37  138  150  123  157  132  187
# 9  1968             12   91  403  552  368  325  418  484

# %%
# INSERT MANUALLY MAXIMUM POSSIBLE POINT
# https://www.imo-official.org/year_info.aspx?year=

new_column_name = ["max_p1", "max_p2", "max_p3", "max_p4", "max_p5", "max_p6"]
new_data = np.array([
    [5, 8, 7, 5, 8, 7],
    [8, 6, 6, 5, 7, 7],
    [6, 7, 7, 6, 7, 7],
    [6, 6, 8, 5, 7, 6],
    [6, 7, 7, 6, 6, 8],
    [7, 7, 6, 6, 7, 9],
    [4, 6, 8, 6, 7, 9],
    [6, 7, 7, 5, 7, 8],
    [6, 7, 8, 6, 7, 8],
    [6, 7, 7, 5, 7, 8],
    [5, 7, 7, 6, 7, 8],
    [5, 7, 8, 6, 6, 8],
    [5, 7, 9, 6, 7, 8],
    [5, 6, 7, 7, 7, 8],
    [6, 6, 8, 6, 6, 8],
    [5, 6, 8, 6, 7, 8],
    [6, 7, 7, 6, 6, 8],
    [5, 7, 8, 6, 7, 7],
    [6, 6, 7, 6, 7, 8],
    [6, 6, 8, 6, 6, 8],
    [6, 7, 7, 6, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7],
    [7, 7, 7, 7, 7, 7]
])
new_data = np.transpose(new_data)

for i, col_name in enumerate(new_column_name):
    df[col_name] = new_data[i]

df
# Out:
#     year  count_country  all    p1    p2    p3    p4    p5    p6  max_p1  \
# 0   1959              2    9    25    55    38    19    13    23       5
# 1   1960              1    8    38    26    12    36    18    17       8
# 2   1961              2    9    29    28    23    24    27    17       6
# 3   1962              3   17    92    77    83    67    71    38       6
# 4   1963              2   16    56    52    31    22    38    97       6
# 5   1964              9   72   412   310   382   107   274   352       7
# 6   1965             10   80   219   216   322   335   303   220       4
# 7   1966              7   27   144   163   126   127   135   198       6
# 8   1967              8   37   138   150   123   157   132   187       6
# 9   1968             12   91   403   552   368   325   418   484       6
# 10  1969             14  112   286   489   467   254   468   273       5
# 11  1970              7   35   122   208    53   173   118    84       5
# ...

# %%
# NORMALIZING
for i in range(1, 7):
    formula = ((1 - ((df[f"p{i}"] / df["all"] )/ df[f"max_p{i}"])) * 10)
    df[f"normalized_p{i}"] = formula
    
display(df)

# Rename & Rearrange column
df = df[["year","count_country","all","normalized_p1","normalized_p2","normalized_p3","normalized_p4","normalized_p5","normalized_p6"]]
column_mapping = {
    "year": "year",
    "count_country": "count_country",
    "all": "all",
    "normalized_p1": "p1",
    "normalized_p2": "p2",
    "normalized_p3": "p3",
    "normalized_p4": "p4",
    "normalized_p5": "p5",
    "normalized_p6": "p6"
}
df = df.rename(columns=column_mapping)
df
# Out:
#     year  count_country  all    p1    p2    p3    p4    p5    p6  max_p1  \
# 0   1959              2    9    25    55    38    19    13    23       5
# 1   1960              1    8    38    26    12    36    18    17       8
# 2   1961              2    9    29    28    23    24    27    17       6
# 3   1962              3   17    92    77    83    67    71    38       6
# 4   1963              2   16    56    52    31    22    38    97       6
# 5   1964              9   72   412   310   382   107   274   352       7
# 6   1965             10   80   219   216   322   335   303   220       4
# 7   1966              7   27   144   163   126   127   135   198       6
# 8   1967              8   37   138   150   123   157   132   187       6
# 9   1968             12   91   403   552   368   325   418   484       6
# 10  1969             14  112   286   489   467   254   468   273       5
# 11  1970              7   35   122   208    53   173   118    84       5
# ...

# %%
df.to_csv('imo_board_groupby_year_normalized.csv', index=False)
